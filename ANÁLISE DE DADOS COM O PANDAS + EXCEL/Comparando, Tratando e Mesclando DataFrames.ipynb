# %% [markdown]
# # Comparando, Trantando e Mesclando DataFrames

# %%
import pandas as pd
#encoding='latin1', encoding='ISO-8859-1', encoding='utf-8' ou então encoding='cp1252'

vendas = pd.read_csv('dados/Contoso - Vendas  - 2017.csv', sep=';')
#vendas = vendas.drop(['ID Canal','ID Loja','ID Produto'], axis=1)
produtos = pd.read_csv('dados/Contoso - Cadastro Produtos.csv', sep=';')
lojas = pd.read_csv('dados/Contoso - Lojas.csv', sep=';')
clientes = pd.read_csv('dados/Contoso - Clientes.csv', sep=';')
#Excluindo Colunas
#clientes = clientes.drop(['Unnamed: 7','Unnamed: 8','Unnamed: 9','Unnamed: 10'], axis=1) #Axis=1 Colunas =0 Linhas

display(vendas)
display(produtos)
display(lojas)
display(clientes)
# Out:
#         Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  \
# 0                     1    01/01/2017    02/01/2017         1       86
# 1                     2    01/01/2017    06/01/2017         5      308
# 2                     3    01/01/2017    01/01/2017         0      294
# 3                     4    01/01/2017    01/01/2017         0      251
# 4                     5    01/01/2017    07/01/2017         6       94
# ...                 ...           ...           ...       ...      ...
# 980637           980638    31/12/2017    31/12/2017         0      194
# 980638           980639    31/12/2017    06/01/2018         6       32
# 980639           980640    31/12/2017    03/01/2018         3      210
# 980640           980641    31/12/2017    31/12/2017         0       53
# 980641           980642    31/12/2017    31/12/2017         0      309
#
#         ID Produto  ID Promocao  ID Cliente  Quantidade Vendida  \
# ...

# %% [markdown]
# # UNINDO COLUNAS DE DADOS
#
#   Unindo as colunas de uma planilha com a outra.
#
#  nova_dataframe = dataframe1.merge(dataframe2, on='Coluna')

# %%
clientes = clientes[['ID Cliente','E-mail']]
produtos = produtos[['ID Produto','Categoria']]
lojas = lojas[['ID Loja','Nome da Loja']]

# %%
new_vendas = vendas.merge(clientes, on='ID Cliente')
new_vendas = vendas.merge(produtos, on='ID Produto')
new_vendas = vendas.merge(lojas, on='ID Loja')

# %%
display(new_vendas)
# Out:
#         Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  \
# 0                     1    01/01/2017    02/01/2017         1       86
# 1                   203    01/01/2017    08/01/2017         7       86
# 2                   220    01/01/2017    01/01/2017         0       86
# 3                   363    01/01/2017    04/01/2017         3       86
# 4                   437    01/01/2017    10/01/2017         9       86
# ...                 ...           ...           ...       ...      ...
# 980637           947015    19/12/2017    19/12/2017         0      273
# 980638           952306    21/12/2017    21/12/2017         0      273
# 980639           967373    26/12/2017    26/12/2017         0      273
# 980640           976154    30/12/2017    31/12/2017         1      273
# 980641           977952    30/12/2017    30/12/2017         0      273
#
#         ID Produto  ID Promocao  ID Cliente  Quantidade Vendida  \
# ...

# %% [markdown]
# # Alterando o nome de uma coluna
# vendas = vendas.rename(columns={'E-mail': 'E-mail do Clientes})

# %%
new_vendas = new_vendas.rename(columns={'Numero da Venda': 'N.Venda', 'Venda': 'D.Venda', 'Nome da Loja': 'N. Loja', })
display(new_vendas)
# Out:
#         N.Venda     D.Venda Data do Envio  ID Canal  ID Loja  ID Produto  \
# 0             1  01/01/2017    02/01/2017         1       86         981
# 1           203  01/01/2017    08/01/2017         7       86         325
# 2           220  01/01/2017    01/01/2017         0       86         777
# 3           363  01/01/2017    04/01/2017         3       86         666
# 4           437  01/01/2017    10/01/2017         9       86        1320
# ...         ...         ...           ...       ...      ...         ...
# 980637   947015  19/12/2017    19/12/2017         0      273         415
# 980638   952306  21/12/2017    21/12/2017         0      273         347
# 980639   967373  26/12/2017    26/12/2017         0      273         364
# 980640   976154  30/12/2017    31/12/2017         1      273         359
# 980641   977952  30/12/2017    30/12/2017         0      273         373
#
#         ID Promocao  ID Cliente  Quantidade Vendida  Quantidade Devolvida  \
# ...
